# %% [markdown]
# <a href="https://colab.research.google.com/github/karenrosas0410-pixel/Estad-stica-2026B-/blob/main/Problemario_Estad%C3%ADstica_Inferencial_II__Karen_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
data={

    "promedio_de_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
    "promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]
}
df=pd.DataFrame(data)
df
# Out:
#     promedio_de_examenes_cortos  promedio_final
# 0                            59              64
# 1                            92              84
# 2                            72              77
# 3                            90              80
# 4                            95              77
# 5                            87              81
# 6                            89              80
# 7                            77              84
# 8                            76              80
# 9                            65              69
# 10                           97              83
# 11                           42              40
# 12                           94              78
# 13                           62              65
# 14                           91              90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   promedio_de_examenes_cortos  15 non-null     int64
#  1   promedio_final               15 non-null     int64
# dtypes: int64(2)
# memory usage: 372.0 bytes

# %%
df.describe()
# Out:
#        promedio_de_examenes_cortos  promedio_final
# count                    15.000000       15.000000
# mean                     79.200000       75.466667
# std                      16.297239       12.123570
# min                      42.000000       40.000000
# 25%                      68.500000       73.000000
# 50%                      87.000000       80.000000
# 75%                      91.500000       82.000000
# max                      97.000000       90.000000

# %%
#definir variables
y=df["promedio_final"]
x=df["promedio_de_examenes_cortos"]

# %%
#3 los datos quieren seguir una linea reacta.

# %%
import matplotlib.pyplot as plt
plt.figure(
    figsize=(10,6),
    dpi=100
)
plt.scatter(
    x,y,
    marker="v",
    color="blue",
    edgecolor="pink",
    alpha=0.9,
    s=60,
    label="promedio final"

)

# %%
#4 calcula el coeficiente de correlacion e interprete el resultado

from scipy.stats import pearsonr
r, valor_p = pearsonr(x,y)
print(f"coeficiente de correlacion (r):{r: 0.4f}")
print(f"valor_p:{valor_p:0.4f}")
# Out:
# coeficiente de correlacion (r): 0.8646
# valor_p:0.0000

# %%
#5 calcule el coeficiente de detrminacion e interprete el resultado r2

print (f"coeficiente de determinacion:")
# Out:
# coeficiente de determinacion:

# %%
# 6 obtenga la recta de regrecion ajustada y grafiquelo sobre el grafico de dispersion
#model.params
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                          24.526822
# promedio_de_examenes_cortos     0.643180
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(
    figsize=(10,6),
    dpi=100
)
plt.scatter(
    x,y,
    marker="v",
    color="blue",
    edgecolor="pink",
    alpha=0.9,
    s=60,
    label="promedio final"

)
plt.plot(
    x,y_calculada,
    color="green",
    linewidth=2,
    label="recta de regrecion ajustada"
)

# %%
#residuales
residuales = modelo.resid

#grafico de dispersion

import matplotlib.pyplot as plt
plt.figure(
    figsize=(10,6),
    dpi=100
)
plt.scatter(
    x,y,
    marker="v",
    color="blue",
    edgecolor="pink",
    alpha=0.9,
    s=60,
    label="promedio final"

)
plt.title(
    "grafico de dispersion",
    fontsize=12,
    fontweight="bold"
)
plt.xlabel(
    "promedio de examenes cortos",
    fontsize=10
)
plt.ylabel(
    "promedio final",
    fontsize=10
)
#tamaño de ticks fuente
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)
#malla
plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.5,
    color="pink"
)
#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon=False,
)
#guarsar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)
plt.axhline(y=0, color="blue", linestyle="--") #linea orizontal

# %%
#7 intervalo de confianza
modelo.conf_int(alpha=0.05)
# Out:
#                                     0          1
# const                        6.441997  42.611646
# promedio_de_examenes_cortos  0.419219   0.867141

# %%
#9 tests de sha´piro
from scipy.stats import shapiro
estadistico, valor_p = shapiro(residuales)
print(f"valor_p:{ valor_p:0.4f}")

#los residuales siguen una distribucion normal
# Out:
# valor_p:0.9018

# %%
#tests de Breusch-pagan
from statsmodels.stats.api import het_breuschpagan
estadistico_1, valor_p_1, estadistico_2, valor_p_2 = het_breuschpagan(residuales,x_constante)
print(f"valor_p:{valor_p_1:0.4f}")
# Out:
# valor_p:0.2289

# %%
# si valor p es menor a alpha se rechaza ho

# ho: no hay heterocesasticidad (varianza uniforme) aplha 0.05+
# hi: hay heterocedasticidad (varianza no uniforme)

# %%
modelo.predict ([1,70])
# Out:
# array([69.54941193])

# %%
modelo.predict([1,75])
# Out:
# array([72.76531124])

# %%
modelo.predict([1,84])
# Out:
# array([78.55393001])

# %%
modelo.predict([1,30])
# Out:
# array([43.82221744])

# %%
#test ANOVA
# y ~ x
from statsmodels.formula.api import ols
modelo_lineal = ols("promedio_final~promedio_de_examenes_cortos", data=df).fit()
tabla_anova = sm.stats. anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                df       sum_sq      mean_sq          F  \
# promedio_de_examenes_cortos   1.0  1538.228959  1538.228959  38.492412
# Residual                     13.0   519.504375    39.961875        NaN
#
#                                PR(>F)
# promedio_de_examenes_cortos  0.000032
# Residual                          NaN

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "categoria de salario":[11,10,8,5,9,7,3,11,8,7,2,9,8,3],
    "ausencias":[18,17,29,36,11,28,35,14,20,32,39,16,31,40]
})
df
# Out:
#     categoria de salario  ausencias
# 0                     11         18
# 1                     10         17
# 2                      8         29
# 3                      5         36
# 4                      9         11
# 5                      7         28
# 6                      3         35
# 7                     11         14
# 8                      8         20
# 9                      7         32
# 10                     2         39
# 11                     9         16
# 12                     8         31
# 13                     3         40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   categoria de salario  14 non-null     int64
#  1   ausencias             14 non-null     int64
# dtypes: int64(2)
# memory usage: 356.0 bytes

# %%
df.describe()
# Out:
#        categoria de salario  ausencias
# count             14.000000  14.000000
# mean               7.214286  26.142857
# std                2.939874   9.882830
# min                2.000000  11.000000
# 25%                5.500000  17.250000
# 50%                8.000000  28.500000
# 75%                9.000000  34.250000
# max               11.000000  40.000000

# %%
#1 definir variables
x=df["categoria de salario"]
y=df["ausencias"]

# %%
#2 diagrama de dispersion
import matplotlib.pyplot as plt
#grafico de dispersion

plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# --- Gráfico de dispersión ---
plt.scatter(
    x, y,
    marker="o",       # forma
    color='pink',     # color de los puntos
    edgecolor='green',    # borde de los puntos
    alpha=0.8,            # transparencia
    s=50,                 # tamaño de los puntos
    label='Categoria de salario' # etiqueta para la leyenda
)
plt.title(
    'Gráfico de dispersión entre salarios y ausencias',
    fontsize=14,
    fontweight='bold'
)

# --- Etiquetas de los ejes ---
plt.xlabel(
    'categoria de salario',
    fontsize=12
)

plt.ylabel(
    'ausencias',
    fontsize=12
)

# --- Fuente de los ticks ---
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# --- Márgenes ---
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Para eliminar márgenes completamente, usar:
# plt.margins(0)

# --- Cuadrícula (opcional, pero didáctica) ---
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.1,
    color="gray"
)

# --- Leyenda ---
plt.legend(
    fontsize=10,
    loc='best',
    frameon=True
)

# --- Nota al pie ---
plt.text(
    0.4, -0.2,
    'Fuente: datos simulados para fines académicos.',
    fontsize=8,
    ha='left',
    va='center',
    transform=plt.gca().transAxes
)

# --- Guardar gráfico ---
plt.savefig(
    "grafico de dispersión",
    bbox_inches='tight'
    )

plt.show()

# %%
# 3 los datos soportan una suposicion de linealidad
# si los datos quieren seguir una linea recta

# %%
#4 Calcula el coeficiente de correlación e interpreta el resultado
from scipy.stats import pearsonr
r, valor_p=pearsonr(x,y)
print(f"coeficiente de correlación (r):{r:0.4f}")
print(f"valor_p:{valor_p:0.4f}")

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05



#       COMO EL VALOR DE r ES IGUAL -0.8801
#       SE DEDUCE QUE H1 ES VERDADEA, POR LO CUAL hay correlación
# Out:
# coeficiente de correlación (r):-0.8801
# valor_p:0.0000

# %%
#5 Calcule el coeficiente de determinación 0= r*r
print(f"coeficiente de determinación:{r**2:0.4f}")
# Out:
# coeficiente de determinación:0.7746

# %%
modelo.params
# Out:
# const                 1.016760
# construccion_casas    1.737564
# dtype: float64

# %%
# 6 obtenga la recta de gresion ajustada
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# const                   47.487603
# categoria de salario    -2.958678
# dtype: float64

# %%
import matplotlib.pyplot as plt

# --- Configuración general del gráfico ---
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# --- Gráfico de dispersión ---
plt.scatter(
    x, y,
    marker="o",       # forma
    color='pink',     # color de los puntos
    edgecolor='green',    # borde de los puntos
    alpha=0.8,            # transparencia
    s=30,                 # tamaño de los puntos
    label='' # etiqueta para la leyenda
)

# --- Gráfico de línea ---
plt.plot(
    x, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    marker='o',           # marcador en cada punto
    markersize=0,         # tamaño del marcador
    markerfacecolor='white',
    markeredgecolor='black',
    label='Recta de regresión'
)

# --- Título ---
plt.title(
    'Gráfico de dispersión entre salario y ausencias',
    fontsize=14,
    fontweight='bold'
)

# --- Etiquetas de los ejes ---
plt.xlabel(
    'categoria de salario',
    fontsize=12
)

plt.ylabel(
    'ausencias',
    fontsize=12
)

# --- Fuente de los ticks ---
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# --- Márgenes ---
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Para eliminar márgenes completamente, usar:
# plt.margins(0)

# --- Cuadrícula (opcional, pero didáctica) ---
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.1,
    color="gray"
)

# --- Leyenda ---
plt.legend(
    fontsize=10,
    loc='best',
    frameon=True
)

# --- Nota al pie ---
plt.text(
    0.4, -0.2,
    'Fuente: datos simulados para fines académicos.',
    fontsize=8,
    ha='left',
    va='center',
    transform=plt.gca().transAxes
)

# --- Guardar gráfico ---
plt.savefig(
    "grafico de dispersión",
    bbox_inches='tight'
    )

plt.show()

# %%
# 7 obtenga un intervalo de confianza del 95%
modelo.conf_int(alpha = 0.05)
# Out:
#                               0          1
# const                 39.707750  55.267457
# categoria de salario  -3.962455  -1.954900

# %%
# 8 calcule los residuales  y trace un nuevo grafico de dispersion
# ¿ parece que se verifican los supuestos?

# los resiuales son la direcencia entre el valos real y el valor que da el modelo
residuales=modelo.resid
residuales
# Out:
# 0     3.057851
# 1    -0.900826
# 2     5.181818
# 3     3.305785
# 4    -9.859504
# 5     1.223140
# 6    -3.611570
# 7    -0.942149
# 8    -3.818182
# 9     5.223140
# 10   -2.570248
# 11   -4.859504
# 12    7.181818
# 13    1.388430
# dtype: float64

# %%
# @title
# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt

# --- Configuración general del gráfico ---
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# --- Gráfico de dispersión ---
plt.scatter(
    x,residuales,
    marker="o",       # forma
    color='pink',     # color de los puntos
    edgecolor='green',    # borde de los puntos
    alpha=0.8,            # transparencia
    s=30,                 # tamaño de los puntos
    label='categoria de salarios (residuales)' # etiqueta para la leyenda
)

plt.axhline(
    y=0,     # Donde está la línea horizontal
    label="Recta de regresión", # Etiqueta
    linestyle = "--", # Estilo de línea
    color = "black",  # color
    linewidth=1.0,   # ancho de línea
    )

# --- Gráfico de línea ---
# plt.plot(
#     x, y_calculada,
#     color='black',   # color de la línea
#     linewidth=1.0,        # grosor de la línea
#     linestyle='--',        # estilo de línea
#     marker='o',           # marcador en cada punto
#     markersize=0,         # tamaño del marcador
#     markerfacecolor='white',
#     markeredgecolor='black',
#     label='Recta de regresión'
# )

# --- Título ---
plt.title(
    'Gráfico de residuales de salarios y de ausencias',
    fontsize=14,
    fontweight='bold'
)

# --- Etiquetas de los ejes ---
plt.xlabel(
    'categoria de salario',
    fontsize=12
)

plt.ylabel(
    'ausencias',
    fontsize=12
)

# --- Fuente de los ticks ---
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# --- Márgenes ---
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Para eliminar márgenes completamente, usar:
# plt.margins(0)

# --- Cuadrícula (opcional, pero didáctica) ---
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.1,
    color="gray"
)

# --- Leyenda ---
plt.legend(
    fontsize=10,
    loc='lower right', # best
    frameon=True
)

# --- Nota al pie ---
plt.text(
    0.4, -0.2,
    'Fuente: datos simulados para fines académicos.',
    fontsize=8,
    ha='left',
    va='center',
    transform=plt.gca().transAxes
)

# --- Guardar gráfico ---
plt.savefig(
    "grafico de dispersión",
    bbox_inches='tight'
    )

plt.show()

# %%
# 9 realice una prueba de shapiro para los residuales e interprete el resultado
#test de shapiro-wilk
# H0: Hay normalidad
# H1: No hay normalidad
# alpha = 0.05

from spacy import displacy
_, valor_p = shapiro(residuales)

print(f"Valor-p: {valor_p: 0.4f}")
# Out:
# Valor-p:  0.8933

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.8932566424098969

# %%
# 10. Realice la prueba de Breusch-Pagan para los residuales
# y comente el resultado.

# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor_p de Breusch-Pagan:  0.4505

# %%
df.describe()
# Out:
#        categoria de salario  ausencias
# count             14.000000  14.000000
# mean               7.214286  26.142857
# std                2.939874   9.882830
# min                2.000000  11.000000
# 25%                5.500000  17.250000
# 50%                8.000000  28.500000
# 75%                9.000000  34.250000
# max               11.000000  40.000000

# %%
modelo.predict([1,60])
# Out:
# array([-130.03305785])

# %%
df
# Out:
#     categoria de salario  ausencias
# 0                     11         18
# 1                     10         17
# 2                      8         29
# 3                      5         36
# 4                      9         11
# 5                      7         28
# 6                      3         35
# 7                     11         14
# 8                      8         20
# 9                      7         32
# 10                     2         39
# 11                     9         16
# 12                     8         31
# 13                     3         40

# %%
modelo.params
# Out:
# const                   47.487603
# categoria de salario    -2.958678
# dtype: float64

# %%
#12. Realice una tabla ANOVA e interprete el resultado.

# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Correcting the formula: 'ausencias' as dependent, 'categoria de salario' as independent
# and using Q() for column names with spaces.
modelo_lineal = ols("ausencias ~ Q('categoria de salario')", data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                              df      sum_sq     mean_sq          F    PR(>F)
# Q('categoria de salario')   1.0  983.548996  983.548996  41.243954  0.000033
# Residual                   12.0  286.165289   23.847107        NaN       NaN

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    "gasto_general": [191,170,272,155,280,173,234,116,153,178],
    "unidades": [40,42,53,35,56,39,48,30,37,40]
})

df
# Out:
#    gasto_general  unidades
# 0            191        40
# 1            170        42
# 2            272        53
# 3            155        35
# 4            280        56
# 5            173        39
# 6            234        48
# 7            116        30
# 8            153        37
# 9            178        40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gasto_general  10 non-null     int64
#  1   unidades       10 non-null     int64
# dtypes: int64(2)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#        gasto_general   unidades
# count      10.000000  10.000000
# mean      192.200000  42.000000
# std        53.349581   8.082904
# min       116.000000  30.000000
# 25%       158.750000  37.500000
# 50%       175.500000  40.000000
# 75%       223.250000  46.500000
# max       280.000000  56.000000

# %%
# define una variable dependinte(y) y una independiente(x)

x= df["unidades"]
y= df["gasto_general"]

# %%
import matplotlib.pyplot as plt
#grafico de dispersion

plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# --- Gráfico de dispersión ---
plt.scatter(
    x, y,
    marker="o",       # forma
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia
    s=50,                 # tamaño de los puntos
    label='Gastos Generales' # etiqueta para la leyenda
)
plt.title(
    'Gráfico de dispersión entre unidades y gastos generales',
    fontsize=14,
    fontweight='bold'
)

# --- Etiquetas de los ejes ---
plt.xlabel(
    'Unidades producidas',
    fontsize=12
)

plt.ylabel(
    'Gastos generales',
    fontsize=12
)

# --- Fuente de los ticks ---
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# --- Márgenes ---
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Para eliminar márgenes completamente, usar:
# plt.margins(0)

# --- Cuadrícula (opcional, pero didáctica) ---
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.1,
    color="gray"
)

# --- Leyenda ---
plt.legend(
    fontsize=10,
    loc='best',
    frameon=True
)

# --- Nota al pie ---
plt.text(
    0.4, -0.2,
    'Fuente: datos simulados para fines académicos.',
    fontsize=8,
    ha='left',
    va='center',
    transform=plt.gca().transAxes
)

# --- Guardar gráfico ---
plt.savefig(
    "grafico de dispersión",
    bbox_inches='tight'
    )

plt.show()

# %%
# 3 ¿los datos soportan la posicion de linealidad?
#si los datos quieren seguir una linea recta

# %%
# 4 coeficiente de correlacion
from scipy.stats import pearsonr
r, valor_p = pearsonr(x,y)
print(f"coeficiente de correlacion (r):{r: 0.4f}")
print(f"valor_p:{valor_p:0.4f}")
# Out:
# coeficiente de correlacion (r): 0.9835
# valor_p:0.0000

# %%
# 6 obtenga la recta de gresion ajustada
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# const      -80.442857
# unidades     6.491497
# dtype: float64

# %%
import matplotlib.pyplot as plt

# --- Configuración general del gráfico ---
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# --- Gráfico de dispersión ---
plt.scatter(
    x, y,
    marker="o",       # forma
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia
    s=30,                 # tamaño de los puntos
    label='Gastos Generales' # etiqueta para la leyenda
)

# --- Gráfico de línea ---
plt.plot(
    x, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    marker='o',           # marcador en cada punto
    markersize=0,         # tamaño del marcador
    markerfacecolor='white',
    markeredgecolor='black',
    label='Recta de regresión'
)

# --- Título ---
plt.title(
    'Gráfico de dispersión entre unidades y gastos generales',
    fontsize=14,
    fontweight='bold'
)

# --- Etiquetas de los ejes ---
plt.xlabel(
    'Unidades producidas',
    fontsize=12
)

plt.ylabel(
    'Gastos generales',
    fontsize=12
)

# --- Fuente de los ticks ---
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# --- Márgenes ---
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Para eliminar márgenes completamente, usar:
# plt.margins(0)

# --- Cuadrícula (opcional, pero didáctica) ---
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.1,
    color="gray"
)

# --- Leyenda ---
plt.legend(
    fontsize=10,
    loc='best',
    frameon=True
)

# --- Nota al pie ---
plt.text(
    0.4, -0.2,
    'Fuente: datos simulados para fines académicos.',
    fontsize=8,
    ha='left',
    va='center',
    transform=plt.gca().transAxes
)

# --- Guardar gráfico ---
plt.savefig(
    "grafico de dispersión",
    bbox_inches='tight'
    )

plt.show()

# %%
#5 coeficiente de determinacion
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, y_calculada)
print(f'Coeficiente de determinación: {r2: 0.2%}\n')
# Out:
# Coeficiente de determinación:  96.73%

# %%
# 7 obtenga un intervalo de confisanza
modelo.conf_int(alpha = 0.05)
# Out:
#                    0          1
# const    -121.986373 -38.899341
# unidades    5.518450   7.464543

# %%
# 8 calcule los residuales  y trace un nuevo grafico de dispersion
# ¿ parece que se verifican los supuestos?

# los resiuales son la direcencia entre el valos real y el valor que da el modelo
residuales=modelo.resid
residuales
# Out:
# 0    11.782993
# 1   -22.200000
# 2     8.393537
# 3     8.240476
# 4    -3.080952
# 5     0.274490
# 6     2.851020
# 7     1.697959
# 8    -6.742517
# 9    -1.217007
# dtype: float64

# %%
# @title
# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt

# --- Configuración general del gráfico ---
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# --- Gráfico de dispersión ---
plt.scatter(
    x, residuales,
    marker="o",       # forma
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia
    s=30,                 # tamaño de los puntos
    label='Gastos Generales (residuales)' # etiqueta para la leyenda
)

plt.axhline(
    y=0,     # Donde está la línea horizontal
    label="Recta de regresión", # Etiqueta
    linestyle = "--", # Estilo de línea
    color = "black",  # color
    linewidth=1.0,   # ancho de línea
    )

# --- Gráfico de línea ---
# plt.plot(
#     x, y_calculada,
#     color='black',   # color de la línea
#     linewidth=1.0,        # grosor de la línea
#     linestyle='--',        # estilo de línea
#     marker='o',           # marcador en cada punto
#     markersize=0,         # tamaño del marcador
#     markerfacecolor='white',
#     markeredgecolor='black',
#     label='Recta de regresión'
# )

# --- Título ---
plt.title(
    'Gráfico de residuales de unidades y gastos generales',
    fontsize=14,
    fontweight='bold'
)

# --- Etiquetas de los ejes ---
plt.xlabel(
    'Unidades producidas',
    fontsize=12
)

plt.ylabel(
    'Gastos generales',
    fontsize=12
)

# --- Fuente de los ticks ---
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# --- Márgenes ---
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Para eliminar márgenes completamente, usar:
# plt.margins(0)

# --- Cuadrícula (opcional, pero didáctica) ---
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.1,
    color="gray"
)

# --- Leyenda ---
plt.legend(
    fontsize=10,
    loc='lower right', # best
    frameon=True
)

# --- Nota al pie ---
plt.text(
    0.4, -0.2,
    'Fuente: datos simulados para fines académicos.',
    fontsize=8,
    ha='left',
    va='center',
    transform=plt.gca().transAxes
)

# --- Guardar gráfico ---
plt.savefig(
    "grafico de dispersión",
    bbox_inches='tight'
    )

plt.show()

# %%
# 9 realice una prueba de shapiro para los residuales e interprete el resultado
#test de shapiro-wilk
# H0: Hay normalidad
# H1: No hay normalidad
# alpha = 0.05

from spacy import displacy
_, valor_p = shapiro(residuales)

print(f"Valor-p: {valor_p: 0.4f}")
# Out:
# Valor-p:  0.2205

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.22045077017698533

# %%
# 10. Realice la prueba de Breusch-Pagan para los residuales
# y comente el resultado.

# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor_p de Breusch-Pagan:  0.9858

# %%
df.describe()
# Out:
#        gasto_general   unidades
# count      10.000000  10.000000
# mean      192.200000  42.000000
# std        53.349581   8.082904
# min       116.000000  30.000000
# 25%       158.750000  37.500000
# 50%       175.500000  40.000000
# 75%       223.250000  46.500000
# max       280.000000  56.000000

# %%
modelo.predict([1,60])
# Out:
# array([309.04693878])

# %%
df
# Out:
#    gasto_general  unidades
# 0            191        40
# 1            170        42
# 2            272        53
# 3            155        35
# 4            280        56
# 5            173        39
# 6            234        48
# 7            116        30
# 8            153        37
# 9            178        40

# %%
modelo.params
# Out:
# const      -80.442857
# unidades     6.491497
# dtype: float64

# %%
# 12. Realice una tabla ANOVA e interprete el resultado.

# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
data={

    "construccion_casas":[2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
    "venta_linea_blanca":[5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]
}
df=pd.DataFrame(data)
df
# Out:
#    construccion_casas  venta_linea_blanca
# 0                 2.0                 5.0
# 1                 2.5                 5.5
# 2                 3.2                 6.0
# 3                 3.6                 7.0
# 4                 3.7                 7.2
# 5                 4.0                 7.7
# 6                 4.2                 8.4
# 7                 4.6                 9.0
# 8                 4.8                 9.7
# 9                 5.0                10.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   construccion_casas  10 non-null     float64
#  1   venta_linea_blanca  10 non-null     float64
# dtypes: float64(2)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#        construccion_casas  venta_linea_blanca
# count           10.000000           10.000000
# mean             3.760000            7.550000
# std              0.977753            1.732211
# min              2.000000            5.000000
# 25%              3.300000            6.250000
# 50%              3.850000            7.450000
# 75%              4.500000            8.850000
# max              5.000000           10.000000

# %%
import pandas as pd
data={
    "construccion_casas":[2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
    "venta_linea_blanca":[5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]
}
df=pd.DataFrame(data)
#definir variables
y=df["venta_linea_blanca"]
x=df["construccion_casas"]

# %%
import matplotlib.pyplot as plt
plt.figure(
    figsize=(6,4),
    dpi=100
)
plt.scatter(
    x,y,
    marker="v",
    color="blue",
    edgecolor="pink",
    alpha=0.9,
    s=60,
    label="construccion_casas"
)
plt.title(
    "grafico de dispersion",
    fontsize=12,
    fontweight="bold"
)
plt.xlabel(
    "construccion_casas",
    fontsize=10
)
plt.ylabel(
    "venta_linea_blanca",
    fontsize=10
)
#tamaño de ticks fuente
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False)
#malla
plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.5,
    color="pink"
)
#leyenda
plt.legend(
    fontsize=10,
    loc="best",
    frameon=False,
)
#guarsar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)
plt.axhline(y=0, color="blue", linestyle="--") #linea orizontal
plt.plot(
    x,y,
    color="green",
    linewidth=0.9,
    linestyle="--")

# %%
#3 los datos soportan la posicion de linealidad
# los datos si quieren seguir una linea recta

# %%
#4 coeficiente de correlacion

from scipy.stats import pearsonr
r, valor_p = pearsonr(x,y)
print(f"coeficiente de correlacion (r):{r: 0.4f}")
print(f"valor_p:{valor_p:0.4f}")
# Out:
# coeficiente de correlacion (r): 0.9808
# valor_p:0.0000

# %%
#6 obtenga la recta de regresion ajustada
import statsmodels.api as sm
x_constante= sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)

modelo.params
# Out:
# const                 1.016760
# construccion_casas    1.737564
# dtype: float64

# %%
# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt

# --- Configuración general del gráfico ---
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# --- Gráfico de dispersión ---
plt.scatter(
    x, y,
    marker="o",       # forma
    color='blue',     # color de los puntos
    edgecolor='green',    # borde de los puntos
    alpha=0.8,            # transparencia
    s=30,                 # tamaño de los puntos
    label='ventas_de_linea_blanca' # etiqueta para la leyenda
)

# --- Gráfico de línea ---
plt.plot(
    x, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    marker='o',           # marcador en cada punto
    markersize=0,         # tamaño del marcador
    markerfacecolor='white',
    markeredgecolor='black',
    label='Recta de regresión'
)

# --- Título ---
plt.title(
    'Gráfico de dispersión entre contruccion de casa y ventas linea blanca',
    fontsize=14,
    fontweight="bold"
)

# --- Etiquetas de los ejes ---
plt.xlabel(
    'Construccion de casas',
    fontsize=12
)

plt.ylabel(
    'Ventas linea blanca',
    fontsize=12
)

# --- Fuente de los ticks ---
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# --- Márgenes ---
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Para eliminar márgenes completamente, usar:
# plt.margins(0)

# --- Cuadrícula (opcional, pero didáctica) ---
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.1,
    color="gray"
)

# --- Leyenda ---
plt.legend(
    fontsize=10,
    loc='best',
    frameon=True
)

# --- Nota al pie ---
plt.text(
    0.4, -0.2,
    'Fuente: datos simulados para fines académicos.',
    fontsize=8,
    ha='left',
    va='center',
    transform=plt.gca().transAxes
)

# --- Guardar gráfico ---
plt.savefig(
    "grafico de dispersión",
    bbox_inches='tight'
    )

plt.show()

# %%
# 5. Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, y_calculada)
print(f'Coeficiente de determinación: {r2: 0.2%}\n')
# Out:
# Coeficiente de determinación:  77.46%

# %%
# 7 obtenga un intervalo de confisanza
modelo.conf_int(alpha = 0.05)
# Out:
#                               0          1
# const                 39.707750  55.267457
# categoria de salario  -3.962455  -1.954900

# %%
# 8 calcule los residuales  y trace un nuevo grafico de dispersion
# ¿ parece que se verifican los supuestos?

# los resiuales son la direcencia entre el valos real y el valor que da el modelo
residuales=modelo.resid
residuales
# Out:
# 0     3.057851
# 1    -0.900826
# 2     5.181818
# 3     3.305785
# 4    -9.859504
# 5     1.223140
# 6    -3.611570
# 7    -0.942149
# 8    -3.818182
# 9     5.223140
# 10   -2.570248
# 11   -4.859504
# 12    7.181818
# 13    1.388430
# dtype: float64

# %%
 #@title
# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt

# --- Configuración general del gráfico ---
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# --- Gráfico de dispersión ---
plt.scatter(
    x, residuales,
    marker="o",       # forma
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia
    s=30,                 # tamaño de los puntos
    label='venta de linea blanca (residuales)' # etiqueta para la leyenda
)

plt.axhline(
    y=0,     # Donde está la línea horizontal
    label="Recta de regresión", # Etiqueta
    linestyle = "--", # Estilo de línea
    color = "black",  # color
    linewidth=1.0,   # ancho de línea
    )

# --- Gráfico de línea ---
# plt.plot(
#     x, y_calculada,
#     color='black',   # color de la línea
#     linewidth=1.0,        # grosor de la línea
#     linestyle='--',        # estilo de línea
#     marker='o',           # marcador en cada punto
#     markersize=0,         # tamaño del marcador
#     markerfacecolor='white',
#     markeredgecolor='black',
#     label='Recta de regresión'
# )

# --- Título ---
plt.title(
    'Gráfico de residuales entre construccion de casas y venta de linea blanca',
    fontsize=14,
    fontweight='bold'
)

# --- Etiquetas de los ejes ---
plt.xlabel(
    'construccion de casas',
    fontsize=12
)

plt.ylabel(
    'venta de linea blanca',
    fontsize=12
)

# --- Fuente de los ticks ---
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# --- Márgenes ---
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Para eliminar márgenes completamente, usar:
# plt.margins(0)

# --- Cuadrícula (opcional, pero didáctica) ---
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.1,
    color="gray"
)

# --- Leyenda ---
plt.legend(
    fontsize=10,
    loc='lower right', # best
    frameon=True
)

# --- Nota al pie ---
plt.text(
    0.4, -0.2,
    'Fuente: datos simulados para fines académicos.',
    fontsize=8,
    ha='left',
    va='center',
    transform=plt.gca().transAxes
)

# --- Guardar gráfico ---
plt.savefig(
    "grafico de dispersión",
    bbox_inches='tight'
    )

plt.show()

# %%
# 9 realice una prueba de shapiro para los residuales e interprete el resultado
#test de shapiro-wilk
# H0: Hay normalidad
# H1: No hay normalidad
# alpha = 0.05

from spacy import displacy
_, valor_p = shapiro(residuales)

print(f"Valor-p: {valor_p: 0.4f}")
# Out:
# Valor-p:  0.8933

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.8932566424098969

# %%
# 10. Realice la prueba de Breusch-Pagan para los residuales
# y comente el resultado.

# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor_p de Breusch-Pagan:  0.4505

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    "numero_interrupciones_al_trabajador": [5,10,10,15,15,20,20,25],
    "calificacion_del_trabajador_en_la_prueba_de_hospitalidad": [58,41,45,27,26,12,16,3]
})

df
# Out:
#    numero_interrupciones_al_trabajador  \
# 0                                    5
# 1                                   10
# 2                                   10
# 3                                   15
# 4                                   15
# 5                                   20
# 6                                   20
# 7                                   25
#
#    calificacion_del_trabajador_en_la_prueba_de_hospitalidad
# 0                                                 58
# 1                                                 41
# 2                                                 45
# 3                                                 27
# 4                                                 26
# 5                                                 12
# 6                                                 16
# 7                                                  3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   numero_interrupciones_al_trabajador                       8 non-null      int64
#  1   calificacion_del_trabajador_en_la_prueba_de_hospitalidad  8 non-null      int64
# dtypes: int64(2)
# memory usage: 260.0 bytes

# %%
df.describe()
# Out:
#        numero_interrupciones_al_trabajador  \
# count                             8.000000
# mean                             15.000000
# std                               6.546537
# min                               5.000000
# 25%                              10.000000
# 50%                              15.000000
# 75%                              20.000000
# max                              25.000000
#
#        calificacion_del_trabajador_en_la_prueba_de_hospitalidad
# count                                           8.000000
# mean                                           28.500000
# std                                            18.462317
# min                                             3.000000
# 25%                                            15.000000
# 50%                                            26.500000
# 75%                                            42.000000
# max                                            58.000000

# %%
# 1. Establesca una variable dependiente ( Y )
# y una variable independiente ( X ).

x = df["numero_interrupciones_al_trabajador"]             # variable independiente (con la que se cuenta)
y = df["calificacion_del_trabajador_en_la_prueba_de_hospitalidad"]        # variable de interés (variable dependiente)

# %%
 #@title
# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt

# --- Configuración general del gráfico ---
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# --- Gráfico de dispersión ---
plt.scatter(
    x, y,
    marker="o",       # forma
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia
    s=50,                 # tamaño de los puntos
    label='Calificacion deltrabajador en la prueba de hospitalidad' # etiqueta para la leyenda
)

# --- Gráfico de línea ---
# plt.plot(
#     x, y,
#     color='orange',   # color de la línea
#     linewidth=2.2,        # grosor de la línea
#     linestyle='-',        # estilo de línea
#     marker='o',           # marcador en cada punto
#     markersize=5,         # tamaño del marcador
#     markerfacecolor='white',
#     markeredgecolor='black',
#     label='Datos observados'
# )

# --- Título ---
plt.title(
    'Gráfico de dispersión entre numero interrupciones al trabajador y calificacion del trabajador en la prueba de hospitalidad',
    fontsize=14,
    fontweight='bold'
)

# --- Etiquetas de los ejes ---
plt.xlabel(
    'Numero interrupciones al trabajador',
    fontsize=12
)

plt.ylabel(
    'Calificacion del trabajador en la prueba de hospitalidad',
    fontsize=12
)

# --- Fuente de los ticks ---
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# --- Márgenes ---
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Para eliminar márgenes completamente, usar:
# plt.margins(0)

# --- Cuadrícula (opcional, pero didáctica) ---
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.1,
    color="gray"
)

# --- Leyenda ---
plt.legend(
    fontsize=10,
    loc='best',
    frameon=True
)

# --- Nota al pie ---
plt.text(
    0.4, -0.2,
    'Fuente: datos simulados para fines académicos.',
    fontsize=8,
    ha='left',
    va='center',
    transform=plt.gca().transAxes
)

# --- Guardar gráfico ---
plt.savefig(
    "grafico de dispersión",
    bbox_inches='tight'
    )

plt.show()

# %%
#4. Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(x, y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'Valor p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación: -0.9928
# Valor p:  0.0000

# %%
 #6. Obtenga la recta de regresión ajustada y grafíquelo sobre el
# gráfico de dispersión

import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# const                                  70.5
# numero_interrupciones_al_trabajador    -2.8
# dtype: float64

# %%
# @title
# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt

# --- Configuración general del gráfico ---
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# --- Gráfico de dispersión ---
plt.scatter(
    x, y,
    marker="o",       # forma
    color='purple',     # color de los puntos
    edgecolor='blue',    # borde de los puntos
    alpha=0.8,            # transparencia
    s=30,                 # tamaño de los puntos
    label='calificacion del trabajador en la prueba de hospitalidad' # etiqueta para la leyenda
)

# --- Gráfico de línea ---
plt.plot(
    x, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    marker='o',           # marcador en cada punto
    markersize=0,         # tamaño del marcador
    markerfacecolor='white',
    markeredgecolor='black',
    label='Recta de regresión'
)

# --- Título ---
plt.title(
    'Gráfico de dispersión entre numero interrupciones al trabajador y calificacion del trabajador en la prueba de hospitalidad',
    fontsize=14,
    fontweight='bold'
)

# --- Etiquetas de los ejes ---
plt.xlabel(
    'Numero interrucpciones al trabajador',
    fontsize=12
)

plt.ylabel(
    'Calificacion del trabajador en la prueba de hospitalidad',
    fontsize=12
)

# --- Fuente de los ticks ---
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# --- Márgenes ---
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Para eliminar márgenes completamente, usar:
# plt.margins(0)

# --- Cuadrícula (opcional, pero didáctica) ---
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.1,
    color="gray"
)

# --- Leyenda ---
plt.legend(
    fontsize=10,
    loc='best',
    frameon=True
)

# --- Nota al pie ---
plt.text(
    0.4, -0.2,
    'Fuente: datos simulados para fines académicos.',
    fontsize=8,
    ha='left',
    va='center',
    transform=plt.gca().transAxes
)

# --- Guardar gráfico ---
plt.savefig(
    "grafico de dispersión",
    bbox_inches='tight'
    )

plt.show()

# %%
# 5. Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, y_calculada)
print(f'Coeficiente de determinación: {r2: 0.2%}\n')
# Out:
# Coeficiente de determinación:  98.58%

# %%
modelo.params
# Out:
# const                                  70.5
# numero_interrupciones_al_trabajador    -2.8
# dtype: float64

# %%
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )

# intervalo de confianza = 1 - alpha

modelo.conf_int(alpha = 0.05)
# Out:
#                                              0          1
# const                                65.051384  75.948616
# numero_interrupciones_al_trabajador  -3.136296  -2.463704

# %%
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
# ¿Parece que se verifican los supuestos?

# Los residuales son la diferencia entre el valor real y el valor que da el
# modelo

# residuales = y - y_calculada
residuales = modelo.resid

residuales
# Out:
# 0    1.5
# 1   -1.5
# 2    2.5
# 3   -1.5
# 4   -2.5
# 5   -2.5
# 6    1.5
# 7    2.5
# dtype: float64

# %%
# @title
# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt

# --- Configuración general del gráfico ---
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# --- Gráfico de dispersión ---
plt.scatter(
    x, residuales,
    marker="o",       # forma
    color='purple',     # color de los puntos
    edgecolor='blue',    # borde de los puntos
    alpha=0.8,            # transparencia
    s=30,                 # tamaño de los puntos
    label='Calificaciones del trabajador en la prueba de hospitalidad (residuales)' # etiqueta para la leyenda
)

plt.axhline(
    y=0,     # Donde está la línea horizontal
    label="Recta de regresión", # Etiqueta
    linestyle = "--", # Estilo de línea
    color = "black",  # color
    linewidth=1.0,   # ancho de línea
    )

# --- Gráfico de línea ---
# plt.plot(
#     x, y_calculada,
#     color='black',   # color de la línea
#     linewidth=1.0,        # grosor de la línea
#     linestyle='--',        # estilo de línea
#     marker='o',           # marcador en cada punto
#     markersize=0,         # tamaño del marcador
#     markerfacecolor='white',
#     markeredgecolor='black',
#     label='Recta de regresión'
# )

# --- Título ---
plt.title(
    'Gráfico de residuales de unidades de numero interrupciones altrabajador y calificacion del trabajador en la prueba de hospitalidad',
    fontsize=14,
    fontweight='bold'
)

# --- Etiquetas de los ejes ---
plt.xlabel(
    'Numero interrupciones al trabajador',
    fontsize=12
)

plt.ylabel(
    'Calificacion del trabajador en la prueba de hospitalidad',
    fontsize=12
)

# --- Fuente de los ticks ---
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# --- Márgenes ---
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Para eliminar márgenes completamente, usar:
# plt.margins(0)

# --- Cuadrícula (opcional, pero didáctica) ---
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.1,
    color="gray"
)

# --- Leyenda ---
plt.legend(
    fontsize=10,
    loc='lower right', # best
    frameon=True
)

# --- Nota al pie ---
plt.text(
    0.4, -0.2,
    'Fuente: datos simulados para fines académicos.',
    fontsize=8,
    ha='left',
    va='center',
    transform=plt.gca().transAxes
)

# --- Guardar gráfico ---
plt.savefig(
    "grafico de dispersión",
    bbox_inches='tight'
    )

plt.show()

# %%
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.

# Test de Shapiro-Wilk
# H0: Hay normalidad
# H1: No hay normalidad
# alpha = 0.05

from scipy.stats import shapiro

_, valor_p = shapiro(residuales)

print(f"Valor-p: {valor_p: 0.4f}")
# Out:
# Valor-p:  0.0548

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.054816491127669634

# %%
# 10. Realice la prueba de Breusch-Pagan para los residuales
# y comente el resultado.

# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor_p de Breusch-Pagan:  0.2482

# %%
df.describe()
# Out:
#        numero_interrupciones_al_trabajador  \
# count                             8.000000
# mean                             15.000000
# std                               6.546537
# min                               5.000000
# 25%                              10.000000
# 50%                              15.000000
# 75%                              20.000000
# max                              25.000000
#
#        calificacion_del_trabajador_en_la_prueba_de_hospitalidad
# count                                           8.000000
# mean                                           28.500000
# std                                            18.462317
# min                                             3.000000
# 25%                                            15.000000
# 50%                                            26.500000
# 75%                                            42.000000
# max                                            58.000000

# %%
modelo.predict([1,60])
# Out:
# array([-97.5])

# %%
df
# Out:
#    numero_interrupciones_al_trabajador  \
# 0                                    5
# 1                                   10
# 2                                   10
# 3                                   15
# 4                                   15
# 5                                   20
# 6                                   20
# 7                                   25
#
#    calificacion_del_trabajador_en_la_prueba_de_hospitalidad
# 0                                                 58
# 1                                                 41
# 2                                                 45
# 3                                                 27
# 4                                                 26
# 5                                                 12
# 6                                                 16
# 7                                                  3

# %%
modelo.params
# Out:
# const                                  70.5
# numero_interrupciones_al_trabajador    -2.8
# dtype: float64

# %%
# 12. Realice una tabla ANOVA e interprete el resultado.

# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('numero_interrupciones_al_trabajador ~ calificacion_del_trabajador_en_la_prueba_de_hospitalidad', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                                      df      sum_sq  \
# calificacion_del_trabajador_en_la_prueba_de_hos...  1.0  295.725063
# Residual                                            6.0    4.274937
#
#                                                        mean_sq           F  \
# calificacion_del_trabajador_en_la_prueba_de_hos...  295.725063  415.058824
# Residual                                              0.712490         NaN
#
#                                                           PR(>F)
# calificacion_del_trabajador_en_la_prueba_de_hos...  9.090964e-07
# Residual                                                     NaN
