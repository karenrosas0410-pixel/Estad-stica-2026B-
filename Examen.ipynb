# %% [markdown]
# <a href="https://colab.research.google.com/github/karenrosas0410-pixel/Estad-stica-2026B-/blob/main/Examen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
link= "https://raw.githubusercontent.com/karenrosas0410-pixel/Estad-stica-2026B-/refs/heads/main/diabetes.csv"

import pandas as pd

df = pd.read_csv(link)

df
# Out:
#      Embarazos  Glucosa  Presión_Arterial  Espesor_De_La_Piel  Insulina   IMC  \
# 0            6      148                72                  35         0  33.6
# 1            1       85                66                  29         0  26.6
# 2            8      183                64                   0         0  23.3
# 3            1       89                66                  23        94  28.1
# 4            0      137                40                  35       168  43.1
# ..         ...      ...               ...                 ...       ...   ...
# 763         10      101                76                  48       180  32.9
# 764          2      122                70                  27         0  36.8
# 765          5      121                72                  23       112  26.2
# 766          1      126                60                   0         0  30.1
# 767          1       93                70                  31         0  30.4
#
#      Función_De_Predisposición_A_Diabetes  Edad  Resultado
# 0                                   0.627    50          1
# 1                                   0.351    31          0
# 2                                   0.672    32          1
# 3                                   0.167    21          0
# 4                                   2.288    33          1
# ..                                    ...   ...        ...
# 763                                 0.171    63          0
# 764                                 0.340    27          0
# 765                                 0.245    30          0
# 766                                 0.349    47          1
# 767                                 0.315    23          0
#
# [768 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Embarazos                             768 non-null    int64
#  1   Glucosa                               768 non-null    int64
#  2   Presión_Arterial                      768 non-null    int64
#  3   Espesor_De_La_Piel                    768 non-null    int64
#  4   Insulina                              768 non-null    int64
#  5   IMC                                   768 non-null    float64
#  6   Función_De_Predisposición_A_Diabetes  768 non-null    float64
#  7   Edad                                  768 non-null    int64
#  8   Resultado                             768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.dropna(inplace=True)
df
# Out:
#      Embarazos  Glucosa  Presión_Arterial  Espesor_De_La_Piel  Insulina   IMC  \
# 0            6      148                72                  35         0  33.6
# 1            1       85                66                  29         0  26.6
# 2            8      183                64                   0         0  23.3
# 3            1       89                66                  23        94  28.1
# 4            0      137                40                  35       168  43.1
# ..         ...      ...               ...                 ...       ...   ...
# 763         10      101                76                  48       180  32.9
# 764          2      122                70                  27         0  36.8
# 765          5      121                72                  23       112  26.2
# 766          1      126                60                   0         0  30.1
# 767          1       93                70                  31         0  30.4
#
#      Función_De_Predisposición_A_Diabetes  Edad  Resultado
# 0                                   0.627    50          1
# 1                                   0.351    31          0
# 2                                   0.672    32          1
# 3                                   0.167    21          0
# 4                                   2.288    33          1
# ..                                    ...   ...        ...
# 763                                 0.171    63          0
# 764                                 0.340    27          0
# 765                                 0.245    30          0
# 766                                 0.349    47          1
# 767                                 0.315    23          0
#
# [768 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Embarazos                             768 non-null    int64
#  1   Glucosa                               768 non-null    int64
#  2   Presión_Arterial                      768 non-null    int64
#  3   Espesor_De_La_Piel                    768 non-null    int64
#  4   Insulina                              768 non-null    int64
#  5   IMC                                   768 non-null    float64
#  6   Función_De_Predisposición_A_Diabetes  768 non-null    float64
#  7   Edad                                  768 non-null    int64
#  8   Resultado                             768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#         Embarazos     Glucosa  Presión_Arterial  Espesor_De_La_Piel  \
# count  768.000000  768.000000        768.000000          768.000000
# mean     3.845052  120.894531         69.105469           20.536458
# std      3.369578   31.972618         19.355807           15.952218
# min      0.000000    0.000000          0.000000            0.000000
# 25%      1.000000   99.000000         62.000000            0.000000
# 50%      3.000000  117.000000         72.000000           23.000000
# 75%      6.000000  140.250000         80.000000           32.000000
# max     17.000000  199.000000        122.000000           99.000000
#
#          Insulina         IMC  Función_De_Predisposición_A_Diabetes  \
# count  768.000000  768.000000                            768.000000
# mean    79.799479   31.992578                              0.471876
# std    115.244002    7.884160                              0.331329
# min      0.000000    0.000000                              0.078000
# 25%      0.000000   27.300000                              0.243750
# 50%     30.500000   32.000000                              0.372500
# 75%    127.250000   36.600000                              0.626250
# max    846.000000   67.100000                              2.420000
#
#              Edad   Resultado
# count  768.000000  768.000000
# mean    33.240885    0.348958
# std     11.760232    0.476951
# min     21.000000    0.000000
# 25%     24.000000    0.000000
# 50%     29.000000    0.000000
# 75%     41.000000    1.000000
# max     81.000000    1.000000

# %%
# no usamos Tukey ya que no tenemos variables categoricas con mas de dos grupos

# %%
#Mapa de calor

import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(30, 18))
sns.heatmap(correlation_matrix,
            annot=True,
            cmap='coolwarm',
            fmt=".4f",
            square=True,
            center=0,
            cbar_kws={"shrink": .8})
plt.title('Mapa de Calor de la Matriz de Correlación')
plt.show()

# %%
#Análisis de multicolinealidad
import pandas as pd
# Reload the original DataFrame to ensure 'Resultado' column is present
link= "https://raw.githubusercontent.com/karenrosas0410-pixel/Estad-stica-2026B-/refs/heads/main/diabetes.csv"
df = pd.read_csv(link)

# Store the target variable before modifying df for feature selection
y_target_original = df["Resultado"]

# Redefine df to contain only the independent variables for multicollinearity analysis
df=df[["Embarazos","Glucosa","Presión_Arterial","Espesor_De_La_Piel","Insulina","IMC","Función_De_Predisposición_A_Diabetes","Edad"]]
df
# Out:
#      Embarazos  Glucosa  Presión_Arterial  Espesor_De_La_Piel  Insulina   IMC  \
# 0            6      148                72                  35         0  33.6
# 1            1       85                66                  29         0  26.6
# 2            8      183                64                   0         0  23.3
# 3            1       89                66                  23        94  28.1
# 4            0      137                40                  35       168  43.1
# ..         ...      ...               ...                 ...       ...   ...
# 763         10      101                76                  48       180  32.9
# 764          2      122                70                  27         0  36.8
# 765          5      121                72                  23       112  26.2
# 766          1      126                60                   0         0  30.1
# 767          1       93                70                  31         0  30.4
#
#      Función_De_Predisposición_A_Diabetes  Edad
# 0                                   0.627    50
# 1                                   0.351    31
# 2                                   0.672    32
# 3                                   0.167    21
# 4                                   2.288    33
# ..                                    ...   ...
# 763                                 0.171    63
# 764                                 0.340    27
# 765                                 0.245    30
# 766                                 0.349    47
# 767                                 0.315    23
#
# [768 rows x 8 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Assuming df contains only the independent variables we want to check
X = df

# Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

print("VIF Results:")
print(vif_data)
# Out:
# VIF Results:
#                                 feature        VIF
# 0                             Embarazos   3.275748
# 1                               Glucosa  16.725078
# 2                      Presión_Arterial  14.619512
# 3                    Espesor_De_La_Piel   4.008696
# 4                              Insulina   2.063689
# 5                                   IMC  18.408884
# 6  Función_De_Predisposición_A_Diabetes   3.195626
# 7                                  Edad  13.492985

# %%
#Mapa de calor

import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.corr()
plt.figure(figsize=(30, 18))
sns.heatmap(correlation_matrix,
            annot=True,
            cmap='coolwarm',
            fmt=".4f",
            square=True,
            center=0,
            cbar_kws={"shrink": .8})
plt.title('Mapa de Calor de la Matriz de Correlación')
plt.show()

# %%
#Establecer variables
x=df # df already contains only the independent variables after previous step
y=y_target_original # Use the target variable stored previously

# %%
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el
# gráfico de dispersión

import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# const                                  -0.853894
# Embarazos                               0.020592
# Glucosa                                 0.005920
# Presión_Arterial                       -0.002332
# Espesor_De_La_Piel                      0.000155
# Insulina                               -0.000181
# IMC                                     0.013244
# Función_De_Predisposición_A_Diabetes    0.147237
# Edad                                    0.002621
# dtype: float64

# %%
# @title
# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt

# --- Configuración general del gráfico ---
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# --- Gráfico de dispersión ---
plt.scatter(
    y, y_calculada,
    marker="o",       # forma
    color='blue',     # color de los puntos
    edgecolor='Blue',    # borde de los puntos
    alpha=0.1,            # transparencia
    s=50,                 # tamaño de los puntos
    label='Resultado' # etiqueta para la leyenda
)

# --- Gráfico de línea ---
plt.plot(
    y_calculada, y_calculada,
    color='black',   # color de la línea
    linewidth=1,        # grosor de la línea
    linestyle='--',        # estilo de línea
    marker='o',           # marcador en cada punto
    markersize=0,         # tamaño del marcador
    markerfacecolor='white',
    markeredgecolor='black',
    label='Recta de regresión'
)

# --- Título ---
plt.title(
    '''Gráfico de dispersión entre
    valores reales y valores predichos''',
    fontsize=14,
    fontweight='bold'
)

# --- Etiquetas de los ejes ---
plt.xlabel(
    'valores reales',
    fontsize=12
)
plt.ylabel(
    'valores predichos',
    fontsize=12
)

# --- Fuente de los ticks ---
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# --- Márgenes ---
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Para eliminar márgenes completamente, usar:
# plt.margins(0)

# --- Cuadrícula (opcional, pero didáctica) ---
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.1,
    color="gray"
)

# --- Leyenda ---
plt.legend(
    fontsize=10,
    loc='best',
    frameon=True
)

# --- Nota al pie ---
plt.text(
    0.4, -0.2,
    'Fuente: datos simulados para fines académicos.',
    fontsize=8,
    ha='left',
    va='center',
    transform=plt.gca().transAxes
)

# --- Guardar gráfico ---
plt.savefig(
    "grafico de dispersión",
    bbox_inches='tight'
    )

plt.show()

# %%
# 5. r2      Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, y_calculada)
print(f'Coeficiente de determinación: {r2: 0.2%}\n')
# Out:
# Coeficiente de determinación:  30.33%

# %%
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )

# intervalo de confianza = 1 - alpha

modelo.conf_int(alpha = 0.05)
# Out:
#                                              0         1
# const                                -1.021709 -0.686079
# Embarazos                             0.010521  0.030663
# Glucosa                               0.004909  0.006932
# Presión_Arterial                     -0.003925 -0.000739
# Espesor_De_La_Piel                   -0.002029  0.002338
# Insulina                             -0.000475  0.000114
# IMC                                   0.009146  0.017343
# Función_De_Predisposición_A_Diabetes  0.058792  0.235682
# Edad                                 -0.000419  0.005662

# %%
residuales=modelo.resid
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# Prueba de Shapiro-Wilk--------------------------------------------------------
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 3.220123417928042e-12

# %%
# 10. Realice la prueba de Breusch-Pagan para los residuales
# y comente el resultado.

# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor_p de Breusch-Pagan:  0.0000

# %%
# 12. Realice una tabla ANOVA e interprete el resultado.

# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

from statsmodels.formula.api import ols
import statsmodels.api as sm
import pandas as pd

# Combine independent variables (x) and the target variable (y_target_original) into a single DataFrame for OLS formula
df_anova = x.copy()
df_anova['Resultado'] = y_target_original

# Define the formula using the correct column names from df_anova
formula = 'Resultado ~ Embarazos + Glucosa + Presión_Arterial + Espesor_De_La_Piel + Insulina + IMC + Función_De_Predisposición_A_Diabetes + Edad'

# Fit the OLS model using the formula and the combined DataFrame
modelo_lineal = ols(formula, data=df_anova).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                          df      sum_sq    mean_sq  \
# Embarazos                               1.0    8.591143   8.591143
# Glucosa                                 1.0   34.020758  34.020758
# Presión_Arterial                        1.0    0.123476   0.123476
# Espesor_De_La_Piel                      1.0    0.863789   0.863789
# Insulina                                1.0    0.255349   0.255349
# IMC                                     1.0    6.780158   6.780158
# Función_De_Predisposición_A_Diabetes    1.0    1.817752   1.817752
# Edad                                    1.0    0.458924   0.458924
# Residual                              759.0  121.567819   0.160168
#
#                                                F        PR(>F)
# Embarazos                              53.638189  6.164705e-13
# Glucosa                               212.406175  1.327103e-42
# Presión_Arterial                        0.770911  3.802132e-01
# Espesor_De_La_Piel                      5.393003  2.048132e-02
# Insulina                                1.594251  2.071077e-01
# IMC                                    42.331432  1.398272e-10
# Función_De_Predisposición_A_Diabetes   11.349002  7.929848e-04
# Edad                                    2.865257  9.092163e-02
# Residual                                     NaN           NaN
