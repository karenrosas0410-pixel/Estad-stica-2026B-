# %% [markdown]
# <a href="https://colab.research.google.com/github/karenrosas0410-pixel/Estad-stica-2026B-/blob/main/Proyecto_3_un2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
link= "https://raw.githubusercontent.com/karenrosas0410-pixel/Estad-stica-2026B-/refs/heads/main/StudentPerformanceFactors.csv"

import pandas as pd

df = pd.read_csv(link)

df
# Out:
#       Horas_Estudiadas  Asistencia Participación_Parental Acceso_a_Recursos  \
# 0                   23          84                    Low              High
# 1                   19          64                    Low            Medium
# 2                   24          98                 Medium            Medium
# 3                   29          89                    Low            Medium
# 4                   19          92                 Medium            Medium
# ...                ...         ...                    ...               ...
# 6602                25          69                   High            Medium
# 6603                23          76                   High            Medium
# 6604                20          90                 Medium               Low
# 6605                10          86                   High              High
# 6606                15          67                 Medium               Low
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Horas_Estudiadas               6607 non-null   int64
#  1   Asistencia                     6607 non-null   int64
#  2   Participación_Parental         6607 non-null   object
#  3   Acceso_a_Recursos              6607 non-null   object
#  4   Actividades_Extracurriculares  6607 non-null   object
#  5   Horas_de_Sueño                 6607 non-null   int64
#  6   Puntajes_Anteriores            6607 non-null   int64
#  7   Nivel_de_Motivación            6607 non-null   object
#  8   Acceso_a_Internet              6607 non-null   object
#  9   Sesiones_de_Tutoría            6607 non-null   int64
#  10  Ingreso_Familiar               6607 non-null   object
#  11  Calidad_de_Profesor            6529 non-null   object
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#       Horas_Estudiadas  Asistencia Participación_Parental Acceso_a_Recursos  \
# 0                   23          84                    Low              High
# 1                   19          64                    Low            Medium
# 2                   24          98                 Medium            Medium
# 3                   29          89                    Low            Medium
# 4                   19          92                 Medium            Medium
# ...                ...         ...                    ...               ...
# 6602                25          69                   High            Medium
# 6603                23          76                   High            Medium
# 6604                20          90                 Medium               Low
# 6605                10          86                   High              High
# 6606                15          67                 Medium               Low
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6378 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Horas_Estudiadas               6378 non-null   int64
#  1   Asistencia                     6378 non-null   int64
#  2   Participación_Parental         6378 non-null   object
#  3   Acceso_a_Recursos              6378 non-null   object
#  4   Actividades_Extracurriculares  6378 non-null   object
#  5   Horas_de_Sueño                 6378 non-null   int64
#  6   Puntajes_Anteriores            6378 non-null   int64
#  7   Nivel_de_Motivación            6378 non-null   object
#  8   Acceso_a_Internet              6378 non-null   object
#  9   Sesiones_de_Tutoría            6378 non-null   int64
#  10  Ingreso_Familiar               6378 non-null   object
#  11  Calidad_de_Profesor            6378 non-null   object
# ...

# %%
df.describe()
# Out:
#        Horas_Estudiadas   Asistencia  Horas_de_Sueño  Puntajes_Anteriores  \
# count       6378.000000  6378.000000     6378.000000          6378.000000
# mean          19.977109    80.020853        7.034964            75.066165
# std            5.985460    11.550723        1.468033            14.400389
# min            1.000000    60.000000        4.000000            50.000000
# 25%           16.000000    70.000000        6.000000            63.000000
# 50%           20.000000    80.000000        7.000000            75.000000
# 75%           24.000000    90.000000        8.000000            88.000000
# max           44.000000   100.000000       10.000000           100.000000
#
#        Sesiones_de_Tutoría  Actividad_Física  Puntaje_del_Examen
# count          6378.000000       6378.000000         6378.000000
# mean              1.495296          2.972719           67.252117
# std               1.233984          1.028926            3.914217
# ...

# %%
print(df['Nivel_de_Motivación'].unique())
# Out:
# ['Low' 'Medium' 'High']

# %%
df = df.dropna(subset=['Nivel_de_Motivación'])
df
# Out:
#       Horas_Estudiadas  Asistencia Participación_Parental Acceso_a_Recursos  \
# 0                   23          84                    Low              High
# 1                   19          64                    Low            Medium
# 2                   24          98                 Medium            Medium
# 3                   29          89                    Low            Medium
# 4                   19          92                 Medium            Medium
# ...                ...         ...                    ...               ...
# 6602                25          69                   High            Medium
# 6603                23          76                   High            Medium
# 6604                20          90                 Medium               Low
# 6605                10          86                   High              High
# 6606                15          67                 Medium               Low
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntaje_del_Examen'], groups=df['Participación_Parental'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#   High    Low  -1.7334   0.0 -2.0626 -1.4042   True
#   High Medium   -0.999   0.0 -1.2636 -0.7344   True
#    Low Medium   0.7344   0.0  0.4363  1.0326   True
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Participación_Parental"]=df["Participación_Parental"].map({"Low":0,"Medium":1,"High":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental Acceso_a_Recursos  \
# 0                   23          84                       0              High
# 1                   19          64                       0            Medium
# 2                   24          98                       1            Medium
# 3                   29          89                       0            Medium
# 4                   19          92                       1            Medium
# ...                ...         ...                     ...               ...
# 6602                25          69                       2            Medium
# 6603                23          76                       2            Medium
# 6604                20          90                       1               Low
# 6605                10          86                       2              High
# 6606                15          67                       1               Low
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntaje_del_Examen'], groups=df['Acceso_a_Recursos'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#   High    Low  -1.8795   0.0 -2.2071 -1.5518   True
#   High Medium  -0.9468   0.0 -1.2088 -0.6848   True
#    Low Medium   0.9327   0.0   0.633  1.2323   True
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Acceso_a_Recursos"]=df["Acceso_a_Recursos"].map({"Low":0,"Medium":1,"High":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntaje_del_Examen'], groups=df['Actividades_Extracurriculares'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#     No    Yes   0.5032   0.0 0.3077 0.6987   True
# -------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Actividades_Extracurriculares"]=df["Actividades_Extracurriculares"].map({"No":0,"Yes":1})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntaje_del_Examen'], groups=df['Nivel_de_Motivación'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   High    Low  -0.9794    0.0 -1.3115 -0.6474   True
#   High Medium   -0.405 0.0048 -0.7071  -0.103   True
#    Low Medium   0.5744    0.0  0.3086  0.8402   True
# ----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Nivel_de_Motivación"]=df["Nivel_de_Motivación"].map({"Low":0,"Medium":1,"High":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntaje_del_Examen'], groups=df['Acceso_a_Internet'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#     No    Yes   0.7549   0.0 0.3929 1.1169   True
# -------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Acceso_a_Internet"]=df["Acceso_a_Internet"].map({"No":0,"Yes":1})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntaje_del_Examen'], groups=df['Ingreso_Familiar'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   High    Low  -0.9882    0.0 -1.3048 -0.6717   True
#   High Medium  -0.4705 0.0015 -0.7873 -0.1536   True
#    Low Medium   0.5178    0.0  0.2631  0.7725   True
# ----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Ingreso_Familiar"]=df["Ingreso_Familiar"].map({"Low":0,"Medium":1,"High":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntaje_del_Examen'], groups=df['Calidad_de_Profesor'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   High    Low   -0.906    0.0 -1.3224 -0.4896   True
#   High Medium  -0.5632    0.0 -0.8198 -0.3066   True
#    Low Medium   0.3428 0.0971 -0.0462  0.7318  False
# ----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Calidad_de_Profesor"]=df["Calidad_de_Profesor"].map({"Low":0,"Medium":1,"High":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntaje_del_Examen'], groups=df['Tipo_de_Escuela'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1 group2 meandiff p-adj   lower  upper  reject
# ----------------------------------------------------
# Private Public  -0.0924 0.3855 -0.3011 0.1163  False
# ----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Tipo_de_Escuela"]=df["Tipo_de_Escuela"].map({"Public":0,"Private":1})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntaje_del_Examen'], groups=df['Influencia_de_Pares'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1   group2  meandiff p-adj  lower  upper  reject
# ------------------------------------------------------
# Negative  Neutral   0.6329    0.0 0.3229 0.9429   True
# Negative Positive   1.0538    0.0  0.745 1.3626   True
#  Neutral Positive   0.4209 0.0004 0.1638 0.6779   True
# ------------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Influencia_de_Pares"]=df["Influencia_de_Pares"].map({"Negative":0,"Neutral":1,"Positive":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntaje_del_Examen'], groups=df['Discapacidades_de_Aprendizaje'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#     No    Yes  -1.0725   0.0 -1.3852 -0.7598   True
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Discapacidades_de_Aprendizaje"]=df["Discapacidades_de_Aprendizaje"].map({"No":0,"Yes":1})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntaje_del_Examen'], groups=df['Nivel_de_Educación_Parental'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#    group1      group2    meandiff p-adj   lower   upper  reject
# ---------------------------------------------------------------
#     College  High School  -0.4635 0.0001 -0.7268 -0.2002   True
#     College Postgraduate   0.6142    0.0  0.2856  0.9429   True
# High School Postgraduate   1.0778    0.0  0.7754  1.3801   True
# ---------------------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Nivel_de_Educación_Parental"]=df["Nivel_de_Educación_Parental"].map({"High School":0,"College":1,"Postgraduate":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntaje_del_Examen'], groups=df['Distancia_desde_Casa'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1   group2  meandiff p-adj lower  upper  reject
# -----------------------------------------------------
#      Far Moderate   0.4882 0.017 0.0705 0.9059   True
#      Far     Near   1.0154   0.0 0.6237  1.407   True
# Moderate     Near   0.5272   0.0 0.2722 0.7822   True
# -----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Distancia_desde_Casa"]=df["Distancia_desde_Casa"].map({"Far":0,"Moderate":1,"Near":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntaje_del_Examen'], groups=df['Género'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
# Female   Male  -0.0391 0.6937 -0.2337 0.1555  False
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Género"]=df["Género"].map({"Male":0,"Female":1})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
#Mapa de calor

import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(30, 18))
sns.heatmap(correlation_matrix,
            annot=True,
            cmap='coolwarm',
            fmt=".4f",
            square=True,
            center=0,
            cbar_kws={"shrink": .8})
plt.title('Mapa de Calor de la Matriz de Correlación')
plt.show()

# %%
#Análisis de multicolinealidad
df=df[["Horas_Estudiadas","Asistencia","Puntajes_Anteriores","Acceso_a_Internet","Ingreso_Familiar"]]
df
# Out:
#       Horas_Estudiadas  Asistencia  Puntajes_Anteriores  Acceso_a_Internet  \
# 0                   23          84                   73                  1
# 1                   19          64                   59                  1
# 2                   24          98                   91                  1
# 3                   29          89                   98                  1
# 4                   19          92                   65                  1
# ...                ...         ...                  ...                ...
# 6602                25          69                   76                  1
# 6603                23          76                   81                  1
# 6604                20          90                   65                  1
# 6605                10          86                   91                  1
# 6606                15          67                   94                  1
#
#       Ingreso_Familiar
# 0                    0
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Assuming df contains only the independent variables we want to check
X = df

# Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

print("VIF Results:")
print(vif_data)
# Out:
# VIF Results:
#                feature        VIF
# 0     Horas_Estudiadas  10.911953
# 1           Asistencia  24.773830
# 2  Puntajes_Anteriores  20.548278
# 3    Acceso_a_Internet  11.504033
# 4     Ingreso_Familiar   2.092877

# %%
#Mapa de calor

import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.corr()
plt.figure(figsize=(30, 18))
sns.heatmap(correlation_matrix,
            annot=True,
            cmap='coolwarm',
            fmt=".4f",
            square=True,
            center=0,
            cbar_kws={"shrink": .8})
plt.title('Mapa de Calor de la Matriz de Correlación')
plt.show()

# %%
#Establecer variables
x=df[["Asistencia","Horas_Estudiadas","Puntajes_Anteriores"]]
y=df["Puntaje_del_Examen"]

# %%
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el
# gráfico de dispersión

import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_22497/1212448660.py in <cell line: 0>()
#       4 import statsmodels.api as sm
#       5 x_constante = sm.add_constant(x)
# ----> 6 modelo = sm.OLS(y, x_constante).fit()
#       7 y_calculada = modelo.predict(x_constante)
#       8
#
# NameError: name 'y' is not defined

# %%
link= "https://raw.githubusercontent.com/karenrosas0410-pixel/Estad-stica-2026B-/refs/heads/main/StudentPerformanceFactors.csv"

import pandas as pd

df = pd.read_csv(link)

df
# Out:
#       Horas_Estudiadas  Asistencia Participación_Parental Acceso_a_Recursos  \
# 0                   23          84                    Low              High
# 1                   19          64                    Low            Medium
# 2                   24          98                 Medium            Medium
# 3                   29          89                    Low            Medium
# 4                   19          92                 Medium            Medium
# ...                ...         ...                    ...               ...
# 6602                25          69                   High            Medium
# 6603                23          76                   High            Medium
# 6604                20          90                 Medium               Low
# 6605                10          86                   High              High
# 6606                15          67                 Medium               Low
#
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#       Horas_Estudiadas  Asistencia Participación_Parental Acceso_a_Recursos  \
# 0                   23          84                    Low              High
# 1                   19          64                    Low            Medium
# 2                   24          98                 Medium            Medium
# 3                   29          89                    Low            Medium
# 4                   19          92                 Medium            Medium
# ...                ...         ...                    ...               ...
# 6602                25          69                   High            Medium
# 6603                23          76                   High            Medium
# 6604                20          90                 Medium               Low
# 6605                10          86                   High              High
# 6606                15          67                 Medium               Low
#
# ...

# %%
df["Participación_Parental"]=df["Participación_Parental"].map({"Low":0,"Medium":1,"High":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental Acceso_a_Recursos  \
# 0                   23          84                       0              High
# 1                   19          64                       0            Medium
# 2                   24          98                       1            Medium
# 3                   29          89                       0            Medium
# 4                   19          92                       1            Medium
# ...                ...         ...                     ...               ...
# 6602                25          69                       2            Medium
# 6603                23          76                       2            Medium
# 6604                20          90                       1               Low
# 6605                10          86                       2              High
# 6606                15          67                       1               Low
#
# ...

# %%
df["Acceso_a_Recursos"]=df["Acceso_a_Recursos"].map({"Low":0,"Medium":1,"High":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
df["Actividades_Extracurriculares"]=df["Actividades_Extracurriculares"].map({"No":0,"Yes":1})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
df["Nivel_de_Motivación"]=df["Nivel_de_Motivación"].map({"Low":0,"Medium":1,"High":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
df["Acceso_a_Internet"]=df["Acceso_a_Internet"].map({"No":0,"Yes":1})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
df["Ingreso_Familiar"]=df["Ingreso_Familiar"].map({"Low":0,"Medium":1,"High":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
df["Calidad_de_Profesor"]=df["Calidad_de_Profesor"].map({"Low":0,"Medium":1,"High":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
df["Tipo_de_Escuela"]=df["Tipo_de_Escuela"].map({"Public":0,"Private":1})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
df["Influencia_de_Pares"]=df["Influencia_de_Pares"].map({"Negative":0,"Neutral":1,"Positive":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
df["Discapacidades_de_Aprendizaje"]=df["Discapacidades_de_Aprendizaje"].map({"No":0,"Yes":1})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
df["Nivel_de_Educación_Parental"]=df["Nivel_de_Educación_Parental"].map({"High School":0,"College":1,"Postgraduate":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
df["Distancia_desde_Casa"]=df["Distancia_desde_Casa"].map({"Far":0,"Moderate":1,"Near":2})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
df["Género"]=df["Género"].map({"Male":0,"Female":1})
df
# Out:
#       Horas_Estudiadas  Asistencia  Participación_Parental  Acceso_a_Recursos  \
# 0                   23          84                       0                  2
# 1                   19          64                       0                  1
# 2                   24          98                       1                  1
# 3                   29          89                       0                  1
# 4                   19          92                       1                  1
# ...                ...         ...                     ...                ...
# 6602                25          69                       2                  1
# 6603                23          76                       2                  1
# 6604                20          90                       1                  0
# 6605                10          86                       2                  2
# 6606                15          67                       1                  0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6378 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Horas_Estudiadas               6378 non-null   int64
#  1   Asistencia                     6378 non-null   int64
#  2   Participación_Parental         6378 non-null   int64
#  3   Acceso_a_Recursos              6378 non-null   int64
#  4   Actividades_Extracurriculares  6378 non-null   int64
#  5   Horas_de_Sueño                 6378 non-null   int64
#  6   Puntajes_Anteriores            6378 non-null   int64
#  7   Nivel_de_Motivación            6378 non-null   int64
#  8   Acceso_a_Internet              6378 non-null   int64
#  9   Sesiones_de_Tutoría            6378 non-null   int64
#  10  Ingreso_Familiar               6378 non-null   int64
#  11  Calidad_de_Profesor            6378 non-null   int64
# ...

# %%
from sklearn.linear_model import LinearRegression

# Variables
X = df[['Asistencia', 'Horas_Estudiadas', 'Puntajes_Anteriores', 'Acceso_a_Recursos', 'Ingreso_Familiar']]
y = df['Puntaje_del_Examen']

# Modelo
modelo = LinearRegression()
modelo.fit(X, y)

# Coeficientes
print("Intercepto:", modelo.intercept_)
print("Coeficientes:", modelo.coef_)
# Out:
# Intercepto: 40.45339274892805
# Coeficientes: [0.19958419 0.29080594 0.04687965 0.96998867 0.55086878]

# %%
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el
# gráfico de dispersión

import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# const                  42.001345
# Asistencia              0.198457
# Horas_Estudiadas        0.290419
# Puntajes_Anteriores     0.047536
# dtype: float64

# %%
# @title
# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt

# --- Configuración general del gráfico ---
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# --- Gráfico de dispersión ---
plt.scatter(
    y, y_calculada,
    marker="o",       # forma
    color='blue',     # color de los puntos
    edgecolor='Blue',    # borde de los puntos
    alpha=0.1,            # transparencia
    s=50,                 # tamaño de los puntos
    label='Puntaje del Examen (Real)' # etiqueta para la leyenda
)

# --- Gráfico de línea ---
plt.plot(
    y_calculada, y_calculada,
    color='black',   # color de la línea
    linewidth=1,        # grosor de la línea
    linestyle='--',        # estilo de línea
    marker='o',           # marcador en cada punto
    markersize=0,         # tamaño del marcador
    markerfacecolor='white',
    markeredgecolor='black',
    label='Recta de regresión'
)
# --- Título ---
plt.title(
    'Gráfico de dispersión: Puntaje del Examen Real vs. Pronosticado',
    fontsize=14,
    fontweight='bold'
)

# --- Etiquetas de los ejes ---
plt.xlabel(
    y.name, # Using the actual name of the 'y' Series
    fontsize=12
)

plt.ylabel(
    'Puntaje del Examen (Pronosticado)',
    fontsize=12
)

# --- Fuente de los ticks ---
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# --- Márgenes ---
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Para eliminar márgenes completamente, usar:
# plt.margins(0)

# --- Cuadrícula (opcional, pero didáctica) ---
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.1,
    color="gray"
)

# --- Leyenda ---
plt.legend(
    fontsize=10,
    loc='best',
    frameon=True
)
# --- Nota al pie ---
plt.text(
    0.4, -0.2,
    'Fuente: Datos de factores de rendimiento estudiantil.',
    fontsize=8,
    ha='left',
    va='center',
    transform=plt.gca().transAxes
)

# --- Guardar gráfico ---
plt.savefig(
    "grafico de dispersión",
    bbox_inches='tight'
    )

plt.show()

# %%
# 5. r2      Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, y_calculada)
print(f'Coeficiente de determinación: {r2: 0.2%}\n')
# Out:
# Coeficiente de determinación:  56.80%

# %%
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )

# intervalo de confianza = 1 - alpha

modelo.conf_int(alpha = 0.05)
# Out:
#                              0          1
# const                41.408458  42.594233
# Asistencia            0.192987   0.203927
# Horas_Estudiadas      0.279862   0.300976
# Puntajes_Anteriores   0.043147   0.051925

# %%
residuales=modelo.resid
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# Prueba de Shapiro-Wilk--------------------------------------------------------
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/scipy/stats/_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6378.
#   res = hypotest_fun_out(*samples, **kwds)
# valor-p (Shapiro) = 9.084734493060604e-81

# %%
# 10. Realice la prueba de Breusch-Pagan para los residuales
# y comente el resultado.

# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor_p de Breusch-Pagan:  0.6315

# %%
# 12. Realice una tabla ANOVA e interprete el resultado.

# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

from statsmodels.formula.api import ols
# Y ~ X
# Correcting the formula to use only one '~' and specifying the dependent and independent variables.
# Based on the previous linear regression, 'Puntaje_del_Examen' is the dependent variable (y)
# and 'Asistencia', 'Horas_Estudiadas', 'Puntajes_Anteriores' are the independent variables (x).
modelo_lineal = ols('Puntaje_del_Examen ~ Asistencia + Horas_Estudiadas + Puntajes_Anteriores', data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                          df        sum_sq       mean_sq            F  \
# Asistencia              1.0  32896.461629  32896.461629  4967.554455
# Horas_Estudiadas        1.0  19610.099125  19610.099125  2961.237484
# Puntajes_Anteriores     1.0   2985.719042   2985.719042   450.860706
# Residual             6374.0  42210.316629      6.622265          NaN
#
#                            PR(>F)
# Asistencia           0.000000e+00
# Horas_Estudiadas     0.000000e+00
# Puntajes_Anteriores  9.842433e-97
# Residual                      NaN
